# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from openslide import open_slide

# %% [markdown]
# Both the images will looking same.

# %%
# Image which will be taken from Normal lymphnode tile directory 
slide1 = open_slide("C:\\Users\\mr\\OneDrive\\Desktop\\tarang books\\Data Science\\Assignment_dataset\\whole_slide_images\\Normal Lymphnode.svs")
slide1_thumb_600 = slide1.get_thumbnail(size = (600, 600))
slide1_thumb_600_np = np.array(slide1_thumb_600)
plt.imshow(slide1_thumb_600_np)

# %%
# Image which had taken from Reactive hyperplasia tile directory
slide2 = open_slide("C:\\Users\\mr\\OneDrive\\Desktop\\tarang books\\Data Science\\Assignment_dataset\\whole_slide_images\\Reactive hyperplasia.svs")
slide2_thumb_600 = slide2.get_thumbnail(size = (600, 600))
slide2_thumb_600_np = np.array(slide2_thumb_600)
plt.imshow(slide2_thumb_600_np)

# %%
from PIL import Image 
img = Image.open("C:\\Users\\mr\\OneDrive\\Desktop\\tarang books\\Data Science\\Assignment_dataset\\whole_slide_images\\Converted\\Reactive hyperplasia.jpg")
small_img = img.resize((200, 300))
grey_img = small_img.convert('L')  #L is for grey scale
plt.imshow(grey_img)

# %%
img2 = Image.open("C:\\Users\\mr\\OneDrive\\Desktop\\tarang books\\Data Science\\Assignment_dataset\\whole_slide_images\\Converted\\Normal Lymphnode.jpg")
small_img2 = img2.resize((200, 300))
grey_img2 = small_img2.convert('L')  #L is for grey scale
plt.imshow(grey_img2)
